# %% [markdown]
# <a href="https://colab.research.google.com/github/abakarova5665/NLTK/blob/main/chat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Импорт необходимых библиотек

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
from nltk.tokenize import wordpunct_tokenize
import matplotlib
from nltk.draw.dispersion import dispersion_plot
from collections import Counter
#библиотека для выгрузки файлов в гугл коллаб
from google.colab import files
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Загружаем книгу

# %%
text = str(files.upload())
# Out:
#      <input type="file" id="files-ab48ff4f-da2a-474e-84c5-debd311a49f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab48ff4f-da2a-474e-84c5-debd311a49f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Разбиваем текст на слова

# %%
text.lower()
words = text.split()

# %% [markdown]
# # Количество слов

# %%
len(words)
# Out:
# 99553

# %% [markdown]
# # Количество уникальных слов

# %%
len(set(words))
# Out:
# 12818

# %%
len(set(words))/len(words)
# Out:
# 0.12875553725151426

# %% [markdown]
# # Cамое частое, самое редкое и медианное по частоте использования слово

# %%
word_l = [str(words).lower() for word in words]

# %%
cnt = Counter(words)
dict(cnt)
# Out:
# {"{'(1)": 1,
#  'The': 559,
#  'Hunger': 33,
#  "Games.txt':": 1,
#  "b'\\xef\\xbb\\xbfThe": 1,
#  'Games\\r\\n\\r\\n\\r\\nThe': 1,
#  'Games': 48,
#  '1by': 1,
#  'Suzanne': 1,
#  'Collins\\r\\n\\r\\nPART': 1,
#  'I"THE': 1,
#  'TRIBUTES"\\r\\n\\r\\n1.\\r\\n\\r\\nWhen': 1,
#  'I': 3731,
#  'wake': 12,
#  'up,': 43,
#  'the': 5012,
#  'other': 91,
#  'side': 33,
#  'of': 1887,
#  'bed': 19,
#  'is': 627,
#  'cold.': 5,
#  'My': 169,
#  'fingers': 35,
#  'stretch': 9,
#  'out,': 30,
#  'seeking': 2,
#  'Prims': 20,
#  'warmth': 6,
#  'but': 558,
#  'finding': 10,
#  'only': 183,
#  'rough': 3,
#  'canvas': 1,
#  'cover': 14,
#  'mattress.': 1,
#  'She': 86,
#  'must': 120,
#  'have': 574,
#  'had': 196,
#  'bad': 25,
#  'dreams': 4,
#  'and': 2143,
#  'climbed': 6,
#  'in': 1350,
#  'with': 595,
#  'our': 196,
#  'mother.': 8,
#  'Of': 27,
#  'course,': 35,
#  'she': 209,
#  'did.': 11,
#  'This': 75,
#  'day': 45,
#  'reaping.': 5,
#  'prop': 3,
#  'myself': 104,
#  'up': 354,
# ...

# %% [markdown]
# # Cамое часто используемое существительное, прилагательное и глагол

# %% [markdown]
# # График дисперсии слов из п. 2 и 3

# %%
dispersion_plot(words, ['game', 'live', 'die', 'hunger'])

# %% [markdown]
# # Повторить пп. 2-4 с очищенным от стоп-слов текстом
